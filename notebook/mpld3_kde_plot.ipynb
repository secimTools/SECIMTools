# %% [markdown]
# Playing with trying to get hovering tool time with density plots.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import mpld3
import numpy as np
import pandas as pd

# %%
# Create test dataset
dat = pd.DataFrame({'one': np.random.normal(size=1000), 
                    'two': np.random.normal(loc=0.1, size=1000), 
                    'three': np.random.normal(loc=-0.1, size=1000)
                    })

dat.head(3)
# Out:
#         one     three       two
# 0  0.618650 -0.299517 -0.408002
# 1 -0.729034  0.676223 -0.560406
# 2 -0.290377  1.211442  0.669659

# %%
dat.plot(kind='kde')

# %%
fig, ax = plt.subplots(figsize=(8,8))
density = dat.plot(kind='kde', ax=ax)
labels = [x.get_label() for x in density.get_lines()]

t1 = mpld3.plugins.LineLabelTooltip(density.get_lines()[0], labels[0])
t2 = mpld3.plugins.LineLabelTooltip(density.get_lines()[1], labels[1])
t3 = mpld3.plugins.LineLabelTooltip(density.get_lines()[2], labels[2])

mpld3.plugins.connect(fig, t1, t2, t3)
mpld3.display()
# Out:
# <style>
#
# </style>
#
# <div id="fig_el53671400462703935529651564790"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el53671400462703935529651564790", {"axes": [{"xlim": [-8.0, 8.0], "yscale": "linear", "axesbg": "none", "texts": [{"v_baseline": "auto", "h_anchor": "middle", "color": "#000000", "text": "Density", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [-0.067130796370967735, 0.5], "rotation": -90.0, "id": "el5367140046267279568"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#000000", "text": "one", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 12.0, "position": [0.90621849798387089, 0.95362903225806461], "rotation": -0.0, "id": "el5367140046267158096"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#000000", "text": "three", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 12.0, "position": [0.90621849798387089, 0.91196236559139787], "rotation": -0.0, "id": "el5367140046268880080"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#000000", "text": "two", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 12.0, "position": [0.90621849798387089, 0.87029569892473113], "rotation": -0.0, "id": "el5367140046268667408"}], "zoomable": true, "images": [], "xdomain": [-8.0, 8.0], "ylim": [0.0, 0.40000000000000002], "paths": [{"edgecolor": "#000000", "facecolor": "none", "edgewidth": 1.0, "pathcodes": ["M", "L", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000001.0, "alpha": 1, "xindex": 0, "data": "data05", "id": "el5367140046267238032"}], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#000000", "alpha": 1.0, "dasharray": "2,2", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 9, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#000000", "alpha": 1.0, "dasharray": "2,2", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 10, "tickvalues": null}], "lines": [{"color": "#0000FF", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.0, "data": "data01", "id": "el5367140046267796496"}, {"color": "#007F00", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.0, "data": "data02", "id": "el5367140046270458384"}, {"color": "#FF0000", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.0, "data": "data03", "id": "el5367140046298253648"}, {"color": "#0000FF", "yindex": 1, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000002.0, "alpha": 1, "xindex": 0, "linewidth": 1.0, "data": "data04", "id": "el5367140046267279824"}, {"color": "#007F00", "yindex": 2, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000002.0, "alpha": 1, "xindex": 0, "linewidth": 1.0, "data": "data04", "id": "el5367140046268669520"}, {"color": "#FF0000", "yindex": 3, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000002.0, "alpha": 1, "xindex": 0, "linewidth": 1.0, "data": "data04", "id": "el5367140046269801424"}], "markers": [], "id": "el5367140046268600144", "ydomain": [0.0, 0.40000000000000002], "collections": [], "xscale": "linear", "bbox": [0.125, 0.125, 0.77500000000000002, 0.77500000000000002]}], "height": 640.0, "width": 640.0, "plugins": [{"type": "reset"}, {"enabled": false, "button": true, "type": "zoom"}, {"enabled": false, "button": true, "type": "boxzoom"}, {"voffset": 10, "labels": ["one"], "hoffset": 0, "location": "mouse", "type": "tooltip", "id": "el5367140046267796496"}, {"voffset": 10, "labels": ["three"], "hoffset": 0, "location": "mouse", "type": "tooltip", "id": "el5367140046270458384"}, {"voffset": 10, "labels": ["two"], "hoffset": 0, "location": "mouse", "type": "tooltip", "id": "el5367140046298253648"}], "data": {"data04": [[0.8390141969086022, 0.9630376344086022, 0.9213709677419355, 0.8797043010752688], [0.8766486055107527, 0.9630376344086022, 0.921370967 ...
